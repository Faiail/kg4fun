# %%
import os
os.chdir("../..")

# %%
from src.utils import load_json

# %%
connected_components = load_json("./data/processed/dataset1/edges/connected_components.json")

# %%
connected_components
# Out:
# [{'component_id': 0,
#   'edge_types': [[0, 'P144', 0], [0, 'P737', 0]],
#   'edges': [['P144', 'related property', 'P737'],
#    ['P737', 'related property', 'P144']]},
#  {'component_id': 1,
#   'edge_types': [[0, 'P1889', 0], [0, 'P460', 0]],
#   'edges': [['P1889', 'related property', 'P460'],
#    ['P460', 'related property', 'P1889']]},
#  {'component_id': 2, 'edge_types': [[0, 'P155', 0]], 'edges': []},
#  {'component_id': 3, 'edge_types': [[0, 'P361', 0]], 'edges': []},
#  {'component_id': 4, 'edge_types': [[0, 'P156', 0]], 'edges': []},
#  {'component_id': 5, 'edge_types': [[0, 'P2283', 16]], 'edges': []},
#  {'component_id': 6, 'edge_types': [[0, 'P279', 84]], 'edges': []},
#  {'component_id': 7, 'edge_types': [[0, 'P1462', 94]], 'edges': []},
#  {'component_id': 8, 'edge_types': [[0, 'P155', 120]], 'edges': []},
#  {'component_id': 9,
#   'edge_types': [[0, 'P361', 120], [0, 'P279', 120]],
#   'edges': [['P279', 'related property', 'P361']]},
# ...

# %%
len(connected_components)
# Out:
# 29434

# %%
rev_mapping = load_json("./data/processed/dataset1/edges/edge_component_mapping.json")
rev_mapping
# Out:
# [{'edge_type': [0, 'P144', 0], 'component_id': 0},
#  {'edge_type': [0, 'P737', 0], 'component_id': 0},
#  {'edge_type': [0, 'P1889', 0], 'component_id': 1},
#  {'edge_type': [0, 'P460', 0], 'component_id': 1},
#  {'edge_type': [0, 'P155', 0], 'component_id': 2},
#  {'edge_type': [0, 'P361', 0], 'component_id': 3},
#  {'edge_type': [0, 'P156', 0], 'component_id': 4},
#  {'edge_type': [0, 'P2283', 16], 'component_id': 5},
#  {'edge_type': [0, 'P279', 84], 'component_id': 6},
#  {'edge_type': [0, 'P1462', 94], 'component_id': 7},
#  {'edge_type': [0, 'P155', 120], 'component_id': 8},
#  {'edge_type': [0, 'P361', 120], 'component_id': 9},
#  {'edge_type': [0, 'P279', 120], 'component_id': 9},
#  {'edge_type': [0, 'P156', 120], 'component_id': 10},
#  {'edge_type': [0, 'P460', 120], 'component_id': 11},
#  {'edge_type': [0, 'P452', 157], 'component_id': 12},
#  {'edge_type': [1, 'P144', 1], 'component_id': 13},
#  {'edge_type': [1, 'P1365', 1], 'component_id': 14},
# ...

# %%
len(rev_mapping)
# Out:
# 40156
